# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\ADITYA GUPTA\Downloads\Online Casino Games Dataset\online_casino_games_dataset_v2.csv")

# %%
df.head(5)
# Out:
#         casino                 game        provider    rtp volatility jackpot  \
# 0  Guts Casino  Texas Hold'em Bonus         Saucify  98.83     Medium     NaN
# 1       Expekt                Mines        Playtech  98.05        Low     NaN
# 2      Betinia           Mega Vault         Gamomat  95.43  Very High     NaN
# 3     Pinnacle   Casino Hold'em Pro      4ThePlayer  99.50     Medium     NaN
# 4      Winnerz    Solar Star Xtreme  Hacksaw Gaming  97.18       High     NaN
#
#                                 country_availability  min_bet    max_win  \
# 0  AR|BR|CH|CO|CY|DE|EE|ES|IE|IL|KE|MT|NZ|PE|PT|R...     1.00  435957.16
# 1                            BG|HR|ID|LT|NO|PH|SE|TR     0.25    1396.15
# 2                CH|ES|GB|HU|ID|IE|IN|LT|NO|SE|SG|VN     0.10    1180.12
# 3                                     BE|BR|MY|NG|PL     0.05  236507.50
# 4                                     CL|KE|PT|SG|SI     0.20    1093.45
#
# ...

# %%
df['jackpot'].unique()
# Out:
# <StringArray>
# [nan, 'Local', 'Fixed', 'Progressive']
# Length: 4, dtype: str

# %%
df.isnull().sum()
# Out:
# casino                        0
# game                          0
# provider                      0
# rtp                           0
# volatility                    0
# jackpot                 1071543
# country_availability          0
# min_bet                       0
# max_win                       0
# game_type                     0
# game_category                 0
# license_jurisdiction          0
# release_year                  0
# currency                      0
# mobile_compatible             0
# free_spins_feature            0
# bonus_buy_available           0
# max_multiplier           213814
# languages                     0
# last_updated                  0
# dtype: int64

# %%
df['jackpot'] = df['jackpot'].fillna('Not Specified')

# %%
df['max_multiplier'] = df['max_multiplier'].fillna(df['max_multiplier'].mode()[0])

# %%
df.isnull().sum()
# Out:
# casino                  0
# game                    0
# provider                0
# rtp                     0
# volatility              0
# jackpot                 0
# country_availability    0
# min_bet                 0
# max_win                 0
# game_type               0
# game_category           0
# license_jurisdiction    0
# release_year            0
# currency                0
# mobile_compatible       0
# free_spins_feature      0
# bonus_buy_available     0
# max_multiplier          0
# languages               0
# last_updated            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1200000 entries, 0 to 1199999
# Data columns (total 20 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   casino                1200000 non-null  str
#  1   game                  1200000 non-null  str
#  2   provider              1200000 non-null  str
#  3   rtp                   1200000 non-null  float64
#  4   volatility            1200000 non-null  str
#  5   jackpot               1200000 non-null  str
#  6   country_availability  1200000 non-null  str
#  7   min_bet               1200000 non-null  float64
#  8   max_win               1200000 non-null  float64
#  9   game_type             1200000 non-null  str
#  10  game_category         1200000 non-null  str
#  11  license_jurisdiction  1200000 non-null  str
#  12  release_year          1200000 non-null  int64
#  13  currency              1200000 non-null  str
#  14  mobile_compatible     1200000 non-null  bool
# ...

# %%
df['max_multiplier'] = df['max_multiplier'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1200000 entries, 0 to 1199999
# Data columns (total 20 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   casino                1200000 non-null  str
#  1   game                  1200000 non-null  str
#  2   provider              1200000 non-null  str
#  3   rtp                   1200000 non-null  float64
#  4   volatility            1200000 non-null  str
#  5   jackpot               1200000 non-null  str
#  6   country_availability  1200000 non-null  str
#  7   min_bet               1200000 non-null  float64
#  8   max_win               1200000 non-null  float64
#  9   game_type             1200000 non-null  str
#  10  game_category         1200000 non-null  str
#  11  license_jurisdiction  1200000 non-null  str
#  12  release_year          1200000 non-null  int64
#  13  currency              1200000 non-null  str
#  14  mobile_compatible     1200000 non-null  bool
# ...

# %%
df.head(5)
# Out:
#         casino                 game        provider    rtp volatility  \
# 0  Guts Casino  Texas Hold'em Bonus         Saucify  98.83     Medium
# 1       Expekt                Mines        Playtech  98.05        Low
# 2      Betinia           Mega Vault         Gamomat  95.43  Very High
# 3     Pinnacle   Casino Hold'em Pro      4ThePlayer  99.50     Medium
# 4      Winnerz    Solar Star Xtreme  Hacksaw Gaming  97.18       High
#
#          jackpot                               country_availability  min_bet  \
# 0  Not Specified  AR|BR|CH|CO|CY|DE|EE|ES|IE|IL|KE|MT|NZ|PE|PT|R...     1.00
# 1  Not Specified                            BG|HR|ID|LT|NO|PH|SE|TR     0.25
# 2  Not Specified                CH|ES|GB|HU|ID|IE|IN|LT|NO|SE|SG|VN     0.10
# 3  Not Specified                                     BE|BR|MY|NG|PL     0.05
# 4  Not Specified                                     CL|KE|PT|SG|SI     0.20
#
#      max_win game_type     game_category license_jurisdiction  release_year  \
# ...

# %%
df['last_updated'] = pd.to_datetime(df['last_updated'], format='%Y-%m-%d')

# %%
df['last_updated'].dtype
# Out:
# dtype('<M8[us]')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
