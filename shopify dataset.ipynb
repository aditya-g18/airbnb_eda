# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_parquet(r"C:\Users\ADITYA GUPTA\Downloads\Data\test-00002-of-00005.parquet", engine="pyarrow")
df.head()
# Out:
#                                        product_title  \
# 0                           White Melt & Pour, 25lbs
# 1                                   Glass Wasp Traps
# 2  Aolowewin Glow in The Dark Spike Replacement B...
# 3            Free Beautiful Desk Concept Mock-Up Psd
# 4        CARBON EXPRESS X-BUSTER BULLDOG NOCK COLLAR
#
#                                  product_description  \
# 0
# 1  Bring peace of mind to your outdoor gatherings...
# 2  Brand: Aolowewin Color: Yellow Features: 【Rech...
# 3  Visit Download Page Introducing you to a compl...
# 4
#
#                                        product_image  \
# 0  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 1  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 2  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 3  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 4  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
#
#                         potential_product_categories ground_truth_brand  \
# ...

# %%
df.shape
# Out:
# (1932, 7)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1932 entries, 0 to 1931
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   product_title                 1932 non-null   str
#  1   product_description           1932 non-null   str
#  2   product_image                 1932 non-null   object
#  3   potential_product_categories  1932 non-null   object
#  4   ground_truth_brand            1932 non-null   str
#  5   ground_truth_is_secondhand    1932 non-null   bool
#  6   ground_truth_category         1932 non-null   str
# dtypes: bool(1), object(2), str(4)
# memory usage: 1.9+ MB

# %%
df = df.drop(columns="product_image")

# %%
df.shape
# Out:
# (1932, 6)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1932 entries, 0 to 1931
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   product_title                 1932 non-null   str
#  1   product_description           1932 non-null   str
#  2   potential_product_categories  1932 non-null   object
#  3   ground_truth_brand            1932 non-null   str
#  4   ground_truth_is_secondhand    1932 non-null   bool
#  5   ground_truth_category         1932 non-null   str
# dtypes: bool(1), object(1), str(4)
# memory usage: 1.9+ MB
