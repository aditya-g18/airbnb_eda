# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"C:\Users\ADITYA GUPTA\Downloads\Data\IPL_dataset.xlsx")
df.head()
# Out:
#    L2           L3   L6 value batsman_NA value bowler_NA  value extras_byes  \
# 0   1  1st innings  0.1         A Chopra        DW Steyn                NaN
# 1   1  1st innings  0.1         A Mukund      A Chandila                NaN
# 2   1  1st innings  0.1      AB McDonald       IK Pathan                NaN
# 3   1  1st innings  0.1  Abhishek Sharma         DR Sams                NaN
# 4   1  1st innings  0.1  Abhishek Sharma        I Sharma                NaN
#
#    value extras_legbyes  value extras_wides value non_striker_NA  \
# 0                   NaN                 NaN             BJ Hodge
# 1                   NaN                 NaN             CH Gayle
# 2                   NaN                 NaN            CA Pujara
# 3                   NaN                 NaN              PK Garg
# 4                   NaN                 NaN           MA Agarwal
#
#    value runs_batsman  ...  balls_per_over      umpire1        umpire2  \
# ...

# %%
df.shape
# Out:
# (243793, 35)

# %%
df.columns
# Out:
# Index(['L2', 'L3', 'L6', 'value batsman_NA', 'value bowler_NA',
#        'value extras_byes', 'value extras_legbyes', 'value extras_wides',
#        'value non_striker_NA', 'value runs_batsman', 'value runs_extras',
#        'value runs_total', 'value wicket_fielders', 'value wicket_kind',
#        'value wicket_player_out', 'Winning_Team', 'MOM', 'Venue',
#        'competition', 'Match_date', 'match_city', 'match_type', 'overs',
#        'outcome_by', 'margin', 'balls_per_over', 'umpire1', 'umpire2',
#        'MatchID', 'value extras_noballs', 'value runs_non_boundary',
#        'L10 replacements_role', 'L9 replacements_role',
#        'value replacements_role', 'value extras_penalty'],
#       dtype='str')

# %%
Working_cols = [
    'Match_date',           # time trends
    'match_city',           # location analysis
    'Venue',                # ground-wise stats
    'Winning_Team',         # win/loss analysis
    'MOM',                  # Man of the Match
    'value runs_batsman',   # batting runs
    'value runs_total',     # total runs per ball
    'value runs_extras',    # extras
    'value wicket_kind',    # type of dismissal
    'value wicket_player_out',  # who got out
    'margin',               # win by how many runs/wickets
    'outcome_by',           # runs or wickets
    'competition',          # IPL season/year
    'overs',                 # over number
    'value batsman_NA',     # who is batting
    'value bowler_NA'       # who is bowling
]

df_work = df[Working_cols]

# %%
df.shape
# Out:
# (243793, 35)

# %%
df_work.head(2)
# Out:
#   Match_date match_city                   Venue           Winning_Team  \
# 0 2008-05-08    Kolkata            Eden Gardens  Kolkata Knight Riders
# 1 2013-04-29     Jaipur  Sawai Mansingh Stadium       Rajasthan Royals
#
#           MOM  value runs_batsman  value runs_total  value runs_extras  \
# 0  SC Ganguly                   0                 0                  0
# 1   SV Samson                   1                 1                  0
#
#   value wicket_kind value wicket_player_out            margin  outcome_by  \
# 0               NaN                     NaN     Won by 5 runs         5.0
# 1               NaN                     NaN  Won by 4 wickets         4.0
#
#   competition  overs value batsman_NA value bowler_NA
# 0         IPL     20         A Chopra        DW Steyn
# 1         IPL     20         A Mukund      A Chandila

# %%
df_work['value wicket_kind'].value_counts()
# Out:
# value wicket_kind
# caught                   7437
# bowled                   2089
# run out                  1062
# lbw                       750
# caught and bowled         349
# stumped                   345
# retired hurt               15
# hit wicket                 15
# retired out                 3
# obstructing the field       2
# Name: count, dtype: int64

# %%
df_work['competition'].value_counts()
# Out:
# competition
# IPL    243793
# Name: count, dtype: int64
